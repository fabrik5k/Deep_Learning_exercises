# %% [markdown]
# # I'm not a robot, i'm an AI

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import cv2

# %% [markdown]
# # Analisando o alfabeto das respostas

# %%
import os 
import re   

diretorio = '../../datasets/captcha_images/'

lista_arquivos = os.listdir(diretorio)

outputs = []

for arquivo in lista_arquivos:
    arquivo = arquivo.replace('.png', '')
    arquivo = arquivo.replace('.jpg', '')
    numeros = re.findall(r'\d+', arquivo)


    # Convertendo a lista de números em uma string concatenada
    resultado = ''.join(numeros)
    outputs.append(resultado)


string_concatenada = ''.join(outputs)
string_concatenada

# Usando um conjunto (set) para encontrar os valores únicos
unicos = set(string_concatenada)

# Determinando os valores únicos de 0 a 9
numeros_unicos = {str(i) for i in range(10)}  # Criando um set de '0' a '9'
valores_unicos = unicos.intersection(numeros_unicos)
valores_unicos

# %%
import os

# Diretório onde estão as imagens
diretorio = '../../datasets/captcha_images/'

# Lista de arquivos no diretório
lista_arquivos = os.listdir(diretorio)

outputs = []

# Processa os nomes dos arquivos, removendo as extensões e armazenando em 'outputs'
for arquivo in lista_arquivos:
    arquivo = arquivo.replace('.png', '').replace('.jpg', '')
    outputs.append(list(arquivo))

# Verificar o tamanho esperado (pode ser o tamanho da primeira entrada, por exemplo)
tamanho_esperado = len(outputs[0])

# Encontrar as entradas que não têm o tamanho esperado
irregulares = [(i, entrada, len(entrada)) for i, entrada in enumerate(outputs) if len(entrada) != tamanho_esperado]

# Exibir os resultados
print(f"Tamanho esperado: {tamanho_esperado}")
print(f"Total de entradas irregulares: {len(irregulares)}")

# Exibir as entradas irregulares com seus tamanhos
for i, entrada, tamanho in irregulares:
    print(f"Índice: {i}, Entrada: {''.join(entrada)}, Tamanho: {tamanho}")
# Out:
# Tamanho esperado: 5
# Total de entradas irregulares: 1
# Índice: 923, Entrada: samples, Tamanho: 7

# %%
import os 
import re   

diretorio = '../../datasets/captcha_images/'

lista_arquivos = os.listdir(diretorio)

outputs = []

for arquivo in lista_arquivos:
    arquivo = arquivo.replace('.png', '')
    arquivo = arquivo.replace('.jpg', '')
    numeros = re.findall(r'\d+', arquivo)


    # Convertendo a lista de números em uma string concatenada
    resultado = ''.join(numeros)
    outputs.append(resultado)


string_concatenada = ''.join(outputs)
string_concatenada

# Usando um conjunto (set) para encontrar os valores únicos
unicos = set(string_concatenada)

# Determinando os valores únicos de 0 a 9
numeros_unicos = {str(i) for i in range(10)}  # Criando um set de '0' a '9'
valores_unicos = unicos.intersection(numeros_unicos)
valores_unicos

# %%
import re

outputs = []

for arquivo in lista_arquivos:
    arquivo = arquivo.replace('.png', '')
    letras = re.findall(r'[a-zA-Z]+', arquivo)
    resultado = ''.join(letras)
    outputs.append(resultado)

string_concatenada = ''.join(outputs)
string_concatenada


unicos = set(string_concatenada)

alfabeto = set('abcdefghijklmnopqrstuvwxyz')

valores_unicos = unicos.intersection(alfabeto)
valores_unicos

# %% [markdown]
# # Estruturando os dados

# %%
import os    

diretorio = '../../datasets/captcha_images/'

lista_arquivos = os.listdir(diretorio)

outputs = []

x = []

for arquivo in lista_arquivos:
    resposta = arquivo.replace('.png', '').replace('.jpg', '')
    outputs.append(list(resposta))
    x.append(cv2.imread(f'{diretorio}{arquivo}'))

x_sem_Proce = np.array(x)
x_sem_Proce.shape
#tf.keras.utils.to_categorical(outputs)
# Out:
# (1070, 50, 200, 3)

# %% [markdown]
# 23 caracteres unicos no total

# %%
chaves = {
    'a': 1, 'b': 2, 'c': 3, 'd': 4,
    'e': 5, 'f': 6, 'g': 7, 'j': 8,
    'l': 9, 'm': 10, 'n': 11, 'p': 12,
    's': 13, 'w': 14, 'x': 15, 'y': 16,
    '2': 17, '3': 18, '4': 19, '5': 20,
    '6': 21, '7': 22, '8': 23
}



# Substituindo diretamente usando o dicionário
resultado = []
for arr in outputs:
    resultados = [str(chaves.get(s, s)) for s in arr]
    resultado.append(resultados)

# Convertendo strings para inteiros
res = [[int(elemento) for elemento in linha] for linha in resultado]

# Subtraindo 1 de cada valor para ajustar ao formato do one-hot encoding (que começa no zero)
res_ajustado = [[elemento - 1 for elemento in linha] for linha in res]

# Aplicando one-hot encoding para cada elemento em 'res_ajustado' com 23 classes
res_one_hot = [[tf.keras.utils.to_categorical(elemento, num_classes=23) for elemento in linha] for linha in res_ajustado]

# Convertendo para tensor tridimensional
res_one_hot_np = np.array(res_one_hot)

# Verificando o shape da matriz resultante
print(f"Shape da matriz one-hot codificada: {res_one_hot_np.shape}")

y = res_one_hot_np.reshape(1070, 5*23)
# Out:
# Shape da matriz one-hot codificada: (1070, 5, 23)

# %%
x_sem_Proce.shape, y.shape
# Out:
# ((1070, 50, 200, 3), (1070, 115))

# %% [markdown]
# # Realizando processamento de imagem

# %%
imagem_cinza = cv2.cvtColor(x_sem_Proce[0].copy(), cv2.COLOR_BGR2GRAY)

median_blur = cv2.medianBlur(imagem_cinza, 3)
opened = cv2.morphologyEx(imagem_cinza.copy(), cv2.MORPH_OPEN, None)
gaussian3_0 = cv2.GaussianBlur(imagem_cinza, (5,5),0)

plt.figure(figsize=(15, 3))  # Define o tamanho da figura

plt.subplot(1, 3, 1)
plt.imshow(median_blur, cmap='gray')
plt.title("Median Blur")

plt.subplot(1, 3, 2)
plt.imshow(opened,  cmap='gray')
plt.title("Opened")

plt.subplot(1, 3, 3)
plt.imshow(gaussian3_0,  cmap='gray')
plt.title("Gaussian 5_0")
# Out:
# Text(0.5, 1.0, 'Gaussian 5_0')

# %%
# Calculando os filtros de canny com diferentes limiares(Thresholds) para imagem sem o filtro gaussiano
canny_median = cv2.Canny(median_blur,70, 140)
canny_opened = cv2.Canny(opened,70, 140)
canny_gaussian = cv2.Canny(gaussian3_0,70, 140)

plt.figure(figsize=(15, 3))  # Define o tamanho da figura

plt.subplot(1, 3, 1)
plt.imshow(canny_median, cmap='gray')
plt.title("Median Blur")

plt.subplot(1, 3, 2)
plt.imshow(canny_opened,  cmap='gray')
plt.title("Opened")

plt.subplot(1, 3, 3)
plt.imshow(canny_gaussian,  cmap='gray')
plt.title("Gaussian 3_0")

plt.show()

# %% [markdown]
# O método de filtragem Gaussian Blur aparentou menos ruído na hora da detecção de bordas, então será este método que usaremos para pré processar as imagens antes de inseri-las no modelo

# %%
dilat = cv2.dilate(src=imagem_cinza.copy(), # Imagem a ser passada
                    kernel=(3,3), # Tamanho do kernel
                    iterations=2) # Numero de vezes que a erosão é aplicada

plt.subplot(1,2,1)
plt.imshow(dilat, cmap='gray')

plt.subplot(1,2,2)
plt.imshow(gaussian3_0, cmap='gray')

# %%
test = cv2.GaussianBlur(dilat, (5,5),0)
plt.imshow(test, cmap='gray')

# %%
h = cv2.Canny(test.copy(), 240,250)
plt.imshow(h, cmap='gray')

# %%
dilated = cv2.dilate(src=h.copy(), # Imagem a ser passada
                    kernel=(7,7), # Tamanho do kernel
                    iterations=3) # Numero de vezes que a erosão é aplicada

plt.imshow(dilated)

# %%
def test_1(img):
    imagem_cinza = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussian_blur = cv2.GaussianBlur(imagem_cinza, (5,5),0)
    return gaussian_blur

def test_2(img):
    imagem_cinza = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    dilat = cv2.dilate(src=imagem_cinza, # Imagem a ser passada
                    kernel=(3,3), # Tamanho do kernel
                    iterations=2) # Numero de vezes que a erosão é aplicada
    gaussian_blur = cv2.GaussianBlur(dilat, (5,5),0)
    return gaussian_blur

def test_3(img):
    imagem_cinza = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    dilat = cv2.dilate(src=imagem_cinza, # Imagem a ser passada
                    kernel=(3,3), # Tamanho do kernel
                    iterations=2) # Numero de vezes que a erosão é aplicada
    gaussian_blur = cv2.GaussianBlur(dilat, (5,5),0)
    canny = cv2.Canny(gaussian_blur, 240,250)
    return canny

# %% [markdown]
# # Dividindo as imagens por letras e criando dataset

# %%
x_sem_Proce.shape[1:3]
# Out:
# (50, 200)

# %%
mask = np.zeros(x_sem_Proce.shape[1:3], dtype='uint8')
x = []
y = []
for i, img in enumerate(x_sem_Proce):
    imgagem = test_3(img)
    for j in range(0, 100, 20):
        if j==80:
            x.append(imgagem[10:43, 27+j+5:51+j+5])
        else:
            x.append(imgagem[10:43, 27+j:51+j])
        y.append(outputs[i][int(j/20)])

x = np.array(x)
y = np.array(y)

# %% [markdown]
# # Pré processamento

# %%
x.shape
# Out:
# (5350, 33, 24)

# %%
from tensorflow.keras.utils import to_categorical

x = x/255 # Normalizando os valores entre 0 e 1
x= x.reshape(5350, 33, 24, 1)

chaves = {
    'a': 1, 'b': 2, 'c': 3, 'd': 4,
    'e': 5, 'f': 6, 'g': 7, 'j': 8,
    'l': 9, 'm': 10, 'n': 11, 'p': 12,
    's': 13, 'w': 14, 'x': 15, 'y': 16,
    '2': 17, '3': 18, '4': 19, '5': 20,
    '6': 21, '7': 22, '8': 23
}

elementos_chaveados = [chaves[elem] for elem in y] # Covertendo dados qualitativos para quantitativos

y = to_categorical(elementos_chaveados)

# %%
x.shape, y.shape
# Out:
# ((5350, 33, 24, 1), (5350, 24))

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size=0.2, random_state=12)

# %%
x_treino.shape
# Out:
# (4280, 33, 24, 1)

# %% [markdown]
# # Treinamento da CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, AveragePooling2D
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, Adadelta

#Criando modelo de rede neural e adicionando as camadas
modelo = Sequential()

#Usar o padding é same, nao usar é valid
# kernel_size é o tamanho do filtro
# pool_size é o tamanho do quadrante que o pooling ira escolher o valor maximo
modelo.add(Conv2D(filters=64, kernel_size=2, activation='relu', input_shape=(33, 24, 1)))
modelo.add(AveragePooling2D(pool_size=(2,2), padding='valid'))

modelo.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
modelo.add(AveragePooling2D(pool_size=(2,2), padding='valid'))

modelo.add(Flatten())

modelo.add(Dense(84, activation='relu', kernel_initializer='normal'))
modelo.add(Dropout(0.2))

#Adicionando camada densa recebendo 1.024 entradas
modelo.add(Dense(84, activation='relu', kernel_initializer='normal'))
modelo.add(Dropout(0.2))

#Adicionando camada de saída
modelo.add(Dense(y_treino.shape[1], activation='softmax', kernel_initializer='normal'))

# %%
otimizador = Adam() # Otimizador Adam

modelo.compile(loss='categorical_crossentropy', 
               optimizer=otimizador, 
               metrics=['acc'], )

# %%
historico = modelo.fit(x_treino, y_treino, epochs=40, batch_size=100, verbose=1, validation_data=(x_teste, y_teste))
# Out:
# Epoch 1/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - acc: 0.1052 - loss: 3.0331 - val_acc: 0.2570 - val_loss: 2.3744
# Epoch 2/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - acc: 0.2872 - loss: 2.2816 - val_acc: 0.5561 - val_loss: 1.5946
# Epoch 3/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - acc: 0.4935 - loss: 1.6359 - val_acc: 0.6738 - val_loss: 1.1805
# Epoch 4/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - acc: 0.6085 - loss: 1.2822 - val_acc: 0.7364 - val_loss: 0.9680
# Epoch 5/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - acc: 0.6743 - loss: 1.0601 - val_acc: 0.7636 - val_loss: 0.8415
# Epoch 6/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.7098 - loss: 0.9530 - val_acc: 0.7841 - val_loss: 0.7742
# Epoch 7/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - acc: 0.7412 - loss: 0.8503 - val_acc: 0.8009 - val_loss: 0.7241
# Epoch 8/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.7689 - loss: 0.7536 - val_acc: 0.8084 - val_loss: 0.6781
# Epoch 9/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - acc: 0.7829 - loss: 0.7051 - val_acc: 0.8206 - val_loss: 0.6194
# Epoch 10/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - acc: 0.7903 - loss: 0.6480 - val_acc: 0.8299 - val_loss: 0.6056
# Epoch 11/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.8088 - loss: 0.6047 - val_acc: 0.8374 - val_loss: 0.5703
# Epoch 12/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.8214 - loss: 0.5776 - val_acc: 0.8336 - val_loss: 0.5501
# Epoch 13/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - acc: 0.8232 - loss: 0.5478 - val_acc: 0.8439 - val_loss: 0.5254
# Epoch 14/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - acc: 0.8277 - loss: 0.5333 - val_acc: 0.8477 - val_loss: 0.5237
# Epoch 15/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - acc: 0.8412 - loss: 0.4999 - val_acc: 0.8514 - val_loss: 0.5022
# Epoch 16/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - acc: 0.8588 - loss: 0.4454 - val_acc: 0.8458 - val_loss: 0.5030
# Epoch 17/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - acc: 0.8614 - loss: 0.4288 - val_acc: 0.8467 - val_loss: 0.4958
# Epoch 18/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - acc: 0.8657 - loss: 0.4396 - val_acc: 0.8346 - val_loss: 0.5386
# Epoch 19/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.8641 - loss: 0.4078 - val_acc: 0.8636 - val_loss: 0.4808
# Epoch 20/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - acc: 0.8770 - loss: 0.3781 - val_acc: 0.8626 - val_loss: 0.4787
# Epoch 21/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - acc: 0.8689 - loss: 0.3908 - val_acc: 0.8598 - val_loss: 0.4810
# Epoch 22/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - acc: 0.8815 - loss: 0.3509 - val_acc: 0.8664 - val_loss: 0.4772
# Epoch 23/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - acc: 0.8797 - loss: 0.3471 - val_acc: 0.8598 - val_loss: 0.4829
# Epoch 24/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - acc: 0.8925 - loss: 0.3289 - val_acc: 0.8701 - val_loss: 0.4723
# Epoch 25/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.8918 - loss: 0.3220 - val_acc: 0.8598 - val_loss: 0.4864
# Epoch 26/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.8944 - loss: 0.3118 - val_acc: 0.8720 - val_loss: 0.4650
# Epoch 27/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.9042 - loss: 0.2880 - val_acc: 0.8617 - val_loss: 0.4737
# Epoch 28/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - acc: 0.9041 - loss: 0.2932 - val_acc: 0.8701 - val_loss: 0.4819
# Epoch 29/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - acc: 0.9098 - loss: 0.2666 - val_acc: 0.8738 - val_loss: 0.4928
# Epoch 30/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.9050 - loss: 0.2629 - val_acc: 0.8701 - val_loss: 0.4807
# Epoch 31/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.9053 - loss: 0.2627 - val_acc: 0.8682 - val_loss: 0.5005
# Epoch 32/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - acc: 0.9149 - loss: 0.2440 - val_acc: 0.8589 - val_loss: 0.5341
# Epoch 33/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.9128 - loss: 0.2600 - val_acc: 0.8748 - val_loss: 0.4928
# Epoch 34/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - acc: 0.9166 - loss: 0.2386 - val_acc: 0.8551 - val_loss: 0.4919
# Epoch 35/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - acc: 0.9134 - loss: 0.2341 - val_acc: 0.8626 - val_loss: 0.5089
# Epoch 36/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - acc: 0.9186 - loss: 0.2274 - val_acc: 0.8748 - val_loss: 0.4997
# Epoch 37/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - acc: 0.9244 - loss: 0.2012 - val_acc: 0.8720 - val_loss: 0.5219
# Epoch 38/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.9263 - loss: 0.2015 - val_acc: 0.8785 - val_loss: 0.5279
# Epoch 39/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - acc: 0.9306 - loss: 0.1953 - val_acc: 0.8738 - val_loss: 0.5416
# Epoch 40/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - acc: 0.9306 - loss: 0.1898 - val_acc: 0.8682 - val_loss: 0.5258
